# %% [markdown]
# ### Ethical issues in image recognition

# %% [markdown]
# [How Ethical Is Facial Recognition Technology?]("https://towardsdatascience.com/how-ethical-is-facial-recognition-technology-8104db2cb81b")

# %% [markdown]
# My view:
# I feel a bit uncomfortable by the fact that this technoology is used without people giving consent, or even better - getting paid for it. There is an interesting idea of Jaron Lanier (read it in his [book]("https://www.amazon.com/Who-Owns-Future-Jaron-Lanier/dp/1451654979")) that we should start getting paid for providing data from which companies make huge amounts of money.

# %% [markdown]
# ### Image Recognition

# %%
# %matplotlib inline
from IPython.display import Image
Image('download.png')

# %% [markdown]
# This should be two people sitting on the couch. I think I could get what it shows only because I knew what to look out for. The faces are not recognizable, body parts are hard to guess as well but somehow the siluettes are telling me that this is a couch they are sitting on, maybe they have a blanket on their knees.
