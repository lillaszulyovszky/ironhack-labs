# %%
import numpy as np
import pandas as pd

# %%
#read csvs
file1 = pd.read_csv("file1.csv")
file2 = pd.read_csv("file2.csv")
file3 = pd.read_csv("file3.csv")

# %%
#check shape of cvs
file1.shape
# Out:
# (4008, 11)

# %%
#check shape of cvs
file2.shape
# Out:
# (996, 11)

# %%
#check shape of cvs
file3.shape
# Out:
# (7070, 11)

# %%
#check head of cvs
file1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
#check head of cvs
file2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
#check head of cvs
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
#check columns cvs
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
#check columns cvs
file2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
#check columns cvs
file3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
# change the order of file3's columns so it follows the same as other two files
file3=file3[['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto','Number of Open Complaints', 'Policy Type','Vehicle Class','Total Claim Amount']]

# %%
#test
file3.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
#rename file2 ST column name
file2 = file2.rename(columns={ 'ST':'state'})

# %%
#rename file1 st column name
file1 = file1.rename(columns={ 'st':'state'})

# %%
#test
file2.columns
# Out:
# Index(['Customer', 'state', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
#test
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
# make columns lowercase
cols = []
for i in range(len(file1.columns)):
    cols.append(file1.columns[i].lower())
cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
#assign it to our df
file1.columns = cols

# %%
#test
file1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
# make columns lowercase
cols = []
for i in range(len(file2.columns)):
    cols.append(file2.columns[i].lower())
cols
# Out:
# ['customer',
#  'state',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'total claim amount',
#  'policy type',
#  'vehicle class']

# %%
#assign it to our df
file2.columns = cols

# %%
#test
file2.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
# make columns lowercase
cols = []
for i in range(len(file3.columns)):
    cols.append(file3.columns[i].lower())
cols
# Out:
# ['customer',
#  'state',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
#assign it to our df
file3.columns = cols

# %%
#test
file3.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
#test if everything is still fine
file1.shape
# Out:
# (4008, 11)

# %%
#test if everything is still fine
file2.shape
# Out:
# (996, 11)

# %%
#test if everything is still fine
file3.shape
# Out:
# (7070, 11)

# %%
#test if everything is still fine
file1.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
#test if everything is still fine
file2.head()
# Out:
#   customer       state gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints  total claim amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy type  vehicle class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
#test if everything is still fine
file3.head()
# Out:
#   customer       state gender             education  customer lifetime value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    vehicle class  total claim amount
# ...

# %% [markdown]
# All good. We can merge.

# %%
#merge files together
data = pd.concat([file1,file2,file3], axis=0)

# %%
#test
data.shape
# Out:
# (12074, 12)

# %% [markdown]
# All good again, we can move on

# %%
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# state                         object
# dtype: object

# %%
data.head(20)
# Out:
#    customer          st gender             education customer lifetime value  \
# 0   RB50392  Washington    NaN                Master                     NaN
# 1   QZ44356     Arizona      F              Bachelor              697953.59%
# 2   AI49188      Nevada      F              Bachelor             1288743.17%
# 3   WW63253  California      M              Bachelor              764586.18%
# 4   GA49547  Washington      M  High School or Below              536307.65%
# 5   OC83172      Oregon      F              Bachelor              825629.78%
# 6   XZ87318      Oregon      F               College              538089.86%
# 7   CF85061     Arizona      M                Master              721610.03%
# 8   DY87989      Oregon      M              Bachelor             2412750.40%
# 9   BQ94931      Oregon      F               College              738817.81%
# 10  SX51350  California      M               College              473899.20%
# ...

# %%
data.tail(20)
# Out:
#      customer   st gender             education customer lifetime value  \
# 7050  EA54906  NaN      F  High School or Below             7501.661322
# 7051  BC64697  NaN      F               College             11663.98572
# 7052  VV68726  NaN      F  High School or Below             5133.397765
# 7053  QR91631  NaN      F  High School or Below             8732.090534
# 7054  OT56964  NaN      M                Master             9424.256842
# 7055  YX35990  NaN      M                Master             5479.555081
# 7056  RN61682  NaN      F              Bachelor             2114.738469
# 7057  BB10681  NaN      F               College             4140.648654
# 7058  FH43628  NaN      F               College             25464.82059
# 7059  WZ45103  NaN      F              Bachelor             5678.050167
# 7060  CB59349  NaN      M                Master              16261.5855
# 7061  RX91025  NaN      M  High School or Below               19872.262
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   st                         1071 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
#  11  state                      8066 non-null   object
# dtypes: float64(3), object(9)
# memory usage: 1.2+ MB

# %%
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Cleaning steps:
# - Delete the column education and the number of open complaints from the dataframe.
# - (no idea how to do that) Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
# - Check for duplicate rows in the data and remove if any.
# - Filter out the data for customers who have an income of 0 or less.

# %%
data.isna().sum()
# Out:
# customer                      2937
# st                           11003
# gender                        3059
# education                     2937
# customer lifetime value       2944
# income                        2937
# monthly premium auto          2937
# number of open complaints     2937
# policy type                   2937
# vehicle class                 2937
# total claim amount            2937
# state                         4008
# dtype: int64

# %%
data.isna().sum()/len(data)
# Out:
# customer                     0.243250
# st                           0.911297
# gender                       0.253354
# education                    0.243250
# customer lifetime value      0.243830
# income                       0.243250
# monthly premium auto         0.243250
# number of open complaints    0.243250
# policy type                  0.243250
# vehicle class                0.243250
# total claim amount           0.243250
# state                        0.331953
# dtype: float64

# %%
#drop education and number of open complaints columns
data = data.drop(['st','education','number of open complaints'],axis=1)

# %%
data.shape
# Out:
# (12074, 9)

# %%
data.head()
# Out:
#   customer gender customer lifetime value   income  monthly premium auto  \
# 0  RB50392    NaN                     NaN      0.0                1000.0
# 1  QZ44356      F              697953.59%      0.0                  94.0
# 2  AI49188      F             1288743.17%  48767.0                 108.0
# 3  WW63253      M              764586.18%      0.0                 106.0
# 4  GA49547      M              536307.65%  36357.0                  68.0
#
#       policy type  vehicle class  total claim amount state
# 0   Personal Auto  Four-Door Car            2.704934   NaN
# 1   Personal Auto  Four-Door Car         1131.464935   NaN
# 2   Personal Auto   Two-Door Car          566.472247   NaN
# 3  Corporate Auto            SUV          529.881344   NaN
# 4   Personal Auto  Four-Door Car           17.269323   NaN

# %%
#check for missing values
data.isna().all(axis=1).dropna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12069    False
# 12070    False
# 12071    False
# 12072    False
# 12073    False
# Length: 12074, dtype: bool

# %%
data.loc[data.isnull().any(axis=1)]
# Out:
#      customer gender customer lifetime value   income  monthly premium auto  \
# 0     RB50392    NaN                     NaN      0.0                1000.0
# 1     QZ44356      F              697953.59%      0.0                  94.0
# 2     AI49188      F             1288743.17%  48767.0                 108.0
# 3     WW63253      M              764586.18%      0.0                 106.0
# 4     GA49547      M              536307.65%  36357.0                  68.0
# ...       ...    ...                     ...      ...                   ...
# 4333  RI52095      M                     NaN  51878.0                  66.0
# 4380  HF88410    NaN                     NaN  36765.0                  66.0
# 4588  MW80236      M                     NaN      0.0                  70.0
# 4869  TO60700      F                     NaN  25859.0                  74.0
# 4988  SV62436    NaN              304179.16%  13789.0                  79.0
#
# ...

# %%
data = data[~data.isna().all(axis=1)]

# %%
data.shape
# Out:
# (9137, 9)

# %%
data = data.reset_index(drop=True)

# %%
#checking for duplicates and removing them
data = data.drop_duplicates()

# %%
#filter out the data for customers who have an income of 0 or less
low_income = data.loc[data.income > 0]

# %%
low_income.sort_values('income', ascending=False)
# Out:
#      customer gender customer lifetime value   income  monthly premium auto  \
# 1753  CJ31839      M              285952.89%  99981.0                  71.0
# 2309  GL69461      F             2628.468543  99961.0                  66.0
# 532   JS42382   Male              617291.42%  99960.0                  76.0
# 932   ST43550      M              572732.71%  99934.0                  71.0
# 4814  GA27295      F             39365.29616  99875.0                 108.0
# ...       ...    ...                     ...      ...                   ...
# 6789  LM83004      M             12552.64705  10147.0                  67.0
# 45    HG65722    NaN             1281910.29%  10105.0                 172.0
# 7961  QG39997      F               4212.8026  10097.0                 110.0
# 1771  TF82172      M              401613.28%  10074.0                 107.0
# 5634  RJ39700      M             4914.035833  10037.0                  71.0
#
# ...

# %%
data.select_dtypes(np.number)
# Out:
#        income  monthly premium auto  total claim amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 9132  71941.0                  73.0          198.234764
# 9133  21604.0                  79.0          379.200000
# 9134      0.0                  85.0          790.784983
# 9135  21941.0                  96.0          691.200000
# 9136      0.0                  77.0          369.600000
#
# [9137 rows x 3 columns]

# %%
data_nums = data._get_numeric_data()

# %%
data_cats = data.drop(columns=data_nums.columns)

# %%
data_nums
# Out:
#        income  monthly premium auto  total claim amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 9132  71941.0                  73.0          198.234764
# 9133  21604.0                  79.0          379.200000
# 9134      0.0                  85.0          790.784983
# 9135  21941.0                  96.0          691.200000
# 9136      0.0                  77.0          369.600000
#
# [9137 rows x 3 columns]

# %%
data_cats
# Out:
#      customer gender customer lifetime value     policy type  vehicle class  \
# 0     RB50392    NaN                     NaN   Personal Auto  Four-Door Car
# 1     QZ44356      F              697953.59%   Personal Auto  Four-Door Car
# 2     AI49188      F             1288743.17%   Personal Auto   Two-Door Car
# 3     WW63253      M              764586.18%  Corporate Auto            SUV
# 4     GA49547      M              536307.65%   Personal Auto  Four-Door Car
# ...       ...    ...                     ...             ...            ...
# 9132  LA72316      M             23405.98798   Personal Auto  Four-Door Car
# 9133  PK87824      F             3096.511217  Corporate Auto  Four-Door Car
# 9134  TD14365      M             8163.890428  Corporate Auto  Four-Door Car
# 9135  UP19263      M             7524.442436   Personal Auto  Four-Door Car
# 9136  Y167826      M             2611.836866  Corporate Auto   Two-Door Car
#
#            state
# 0            NaN
# 1            NaN
# ...

# %%
data_cats['customer lifetime value'].value_counts()
# Out:
# 2300.691547    6
# 13727.79972    6
# 9031.214859    6
# 3237.996209    6
# 6521.368813    6
#               ..
# 5129.608404    1
# 515936.97%     1
# 5126.54272     1
# 5124.984391    1
# 2744.172816    1
# Name: customer lifetime value, Length: 8211, dtype: int64

# %%
def clean_clv(x):
    return float(str(x).replace('%', ''))*100

data_cats['customer lifetime value'] = data_cats['customer lifetime value'].apply(clean_clv)

# %%
data_cats
# Out:
#      customer gender  customer lifetime value     policy type  vehicle class  \
# 0     RB50392    NaN                      NaN   Personal Auto  Four-Door Car
# 1     QZ44356      F             6.979536e+07   Personal Auto  Four-Door Car
# 2     AI49188      F             1.288743e+08   Personal Auto   Two-Door Car
# 3     WW63253      M             7.645862e+07  Corporate Auto            SUV
# 4     GA49547      M             5.363076e+07   Personal Auto  Four-Door Car
# ...       ...    ...                      ...             ...            ...
# 9132  LA72316      M             2.340599e+06   Personal Auto  Four-Door Car
# 9133  PK87824      F             3.096511e+05  Corporate Auto  Four-Door Car
# 9134  TD14365      M             8.163890e+05  Corporate Auto  Four-Door Car
# 9135  UP19263      M             7.524442e+05   Personal Auto  Four-Door Car
# 9136  Y167826      M             2.611837e+05  Corporate Auto   Two-Door Car
#
#            state
# 0            NaN
# ...
